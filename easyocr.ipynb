# %%
import cv2
import matplotlib.pyplot as plt


#手機拍的

img = plt.imread('./IMG_3884.jpg')
plt.imshow(img)

# %%
#切長條狀，左右各半並清楚看到數字

img = plt.imread('./IMG_3884_cut.jpg')
plt.imshow(img)

# %%
#eastocr辨識結果
import easyocr
reader = easyocr.Reader(['ch_sim','en']) # need to run only once to load model into memory
result = reader.readtext('./IMG_3884_cut.jpg')
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
plt.imshow(img)
reader.readtext(img, detail = 0)
# Out:
# ['A22']

# %%
import easyocr

# PIcamera所拍攝

img2 = plt.imread('./realphoto/1.jpg')
plt.imshow(img2)

# %%
img2_test = plt.imread('./realphoto/1_test.jpg')
reader = easyocr.Reader(['ch_sim','en']) # need to run only once to load model into memory
#result = reader.readtext('./realphoto/1_test.jpg')
plt.imshow(img2_test)
reader.readtext(img2_test, detail = 0)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ['II0']

# %%
img3 = plt.imread('./realphoto/2.jpg')
plt.imshow(img3)

# %%
img3_1test = plt.imread('./realphoto/2_1test.jpg')
reader = easyocr.Reader(['ch_sim','en']) # need to run only once to load model into memory
#result = reader.readtext('./realphoto/1_test.jpg')
plt.imshow(img3_1test)
reader.readtext(img3_1test, detail = 0)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ['003']

# %%
img3_2test = plt.imread('./realphoto/2_2test.jpg')
reader = easyocr.Reader(['ch_sim','en']) # need to run only once to load model into memory
#result = reader.readtext('./realphoto/1_test.jpg')
plt.imshow(img3_2test)
reader.readtext(img3_2test, detail = 0)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ['004']

# %%
img3_3test = plt.imread('./realphoto/2_3test.jpg')
reader = easyocr.Reader(['ch_sim','en']) # need to run only once to load model into memory
#result = reader.readtext('./realphoto/1_test.jpg')
plt.imshow(img3_3test)
reader.readtext(img3_3test, detail = 0)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ['O0S']
