# %%
import matplotlib.pyplot as plt
import pytesseract
from PIL import Image

img = plt.imread('./IMG_3884.jpg')
image1 = Image.open('./helloworld.png')
code1 = pytesseract.image_to_string(image1)
plt.imshow(image1)
print(code1)
# Out:
# Hello word !

# %%
image2 = Image.open('./IMG_3884_cut2.jpg')
code2 = pytesseract.image_to_string(image2)
print(code2)
plt.imshow(image2)

# %%
image2 = Image.open('./A2.png')
code2 = pytesseract.image_to_string(image2)
print(code2)
plt.imshow(image2)
# Out:
# A2?
